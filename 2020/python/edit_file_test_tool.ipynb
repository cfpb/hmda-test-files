# %%
import ast
import json
import os
from os.path import join, isfile
from os import listdir, makedirs, path

import pandas as pd
import yaml

#Edit report configurations are located in configurations/edit_report_config.yaml
import lar_generator
from rules_engine import rules_engine

pd.options.display.max_columns = 999
pd.options.display.max_rows = 999
pd.set_option('display.max_colwidth', -1)
# Out:
# /Users/roellr/.pyenv/versions/3.6.9/lib/python3.6/site-packages/pandas/compat/__init__.py:84: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# /Users/roellr/.pyenv/versions/3.6.9/lib/python3.6/site-packages/pandas/compat/__init__.py:84: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
#load configurations
lar_config_file = 'configurations/clean_file_config.yaml'
bank_config = "configurations/ABHINAYAA_config.yaml"
geo_config_file='configurations/geographic_data.yaml'
filepaths_file = 'configurations/test_filepaths.yaml'
lar_schema_file="../schemas/lar_schema.json"
ts_schema_file="../schemas/ts_schema.json"
lar_2018_haeder = []

with open(lar_schema_file, "r") as in_schema:
    lar_schema = in_schema.readlines()
lar_schema = [line.strip("\n") for line in lar_schema]
lar_string = "".join([line for line in lar_schema])
lar_json = json.loads(lar_string)
lar_2018_header = []
for row in lar_json:
    lar_2018_header.append(row["field"])

# %%
#open configuration files and load data
with open(bank_config) as f:
	bank_config_data = yaml.safe_load(f)

with open(lar_config_file, 'r') as f:
	lar_file_config_data = yaml.safe_load(f)

with open(filepaths_file, 'r') as f:
	filepaths = yaml.safe_load(f)

with open(geo_config_file, 'r') as f:
	geo_config = yaml.safe_load(f)

with open(bank_config, 'r') as f:
	bank_config_data = yaml.safe_load(f)

with open(geo_config["zip_code_file"], 'r') as f:
	zip_codes = json.load(f)
zip_codes.append("Exempt")

# %%
geographic_data = pd.read_csv(geo_config['geographic_data_file'], delimiter='|', header=0,
	names=geo_config['file_columns'], dtype=object) #instantiate Census file data as dataframe

#create 11 digit Census Tract codes from 5 digit county and 6 digit tract
geographic_data['county_fips'] = geographic_data.apply(lambda x: str(x.state_code) + str(x.county), axis=1)
geographic_data["tract_fips"] = geographic_data.apply(lambda x: str(x.county_fips) + str(x.tracts), axis=1)

with open(geo_config["zip_code_file"], 'r') as f: 
	zip_codes = json.load(f)
zip_codes.append("Exempt")#add exempt as a valid ZIP Code

#instantiate lar generator to create random LAR and fixed TS data
lar_gen = lar_generator.lar_gen(lar_schema_file=lar_schema_file, ts_schema_file=ts_schema_file)

#instantiate rules engine to check conformity of synthetic data to FIG schema
#rules engine creates edit reports to see which edits were failed by which rows in which file
rules_engine = rules_engine(config_data=lar_file_config_data, state_codes=geo_config["state_codes"], state_codes_rev=geo_config["state_codes_rev"],
	geographic_data=geographic_data, full_lar_file_check=False)
# Out:
# start initialization of LAR generator
# LAR generator initialization complete
# initializing rules engine
# loading config files for rules engine
# opening json schema files
# schema loaded
# rules engine finished initializing

# %%
#set location for edit report CSV writing
edit_report_path = filepaths["edit_report_output_filepath"] 

#get paths to check for clean files (by bank name) 
#store as list to match edit files format
clean_filepath = [filepaths["clean_filepath"].format(bank_name=bank_config_data["name"]["value"])]

#get directories to check for files
bank_test_v_dir = filepaths["validity_filepath"].format(bank_name=bank_config_data["name"]["value"])
bank_test_s_dir = filepaths["syntax_filepath"].format(bank_name=bank_config_data["name"]["value"])
bank_test_q_dir = filepaths["quality_filepath"].format(bank_name=bank_config_data["name"]["value"])
bank_test_q_pass_dir = filepaths["quality_pass_s_v_filepath"].format(bank_name=bank_config_data["name"]["value"])

edit_filepaths = [bank_test_v_dir, bank_test_s_dir, bank_test_q_dir]
print("edit report save path", edit_report_path)
print("clean file dir", clean_filepath)
print("valdity test file dir", bank_test_v_dir)
print("syntax test file dir", bank_test_s_dir)
print("quality test file dir", bank_test_q_dir)
print("s/v clean quality test file dir", bank_test_q_pass_dir)
# Out:
# edit report save path ../edit_reports/
# clean file dir ['../edits_files/Abhinayaa Bank/clean_files/']
# valdity test file dir ../edits_files/Abhinayaa Bank/test_files/validity/
# syntax test file dir ../edits_files/Abhinayaa Bank/test_files/syntax/
# quality test file dir ../edits_files/Abhinayaa Bank/test_files/quality/
# s/v clean quality test file dir ../edits_files/Abhinayaa Bank/test_files/quality_pass_s_v/

# %%
def get_file_names(filepaths):
    """
    filepaths: list of paths to check for files
    file_names: list of files in the path(s)
    """
    file_names = []
    for path in filepaths:
    #concat edit file path to edit file name to make looping easier in edit check
        new_file_names = [path+f for f in listdir(path) if isfile(join(path, f))]
        file_names = file_names + new_file_names
    
    try:
        file_names = [f for f in file_names if '.DS_Store' not in f]
    except:
        print("no DS Store to remove")
    file_names.sort()
    print(len(file_names), "files found in {filepaths}".format(filepaths=filepaths))
    return file_names

def generate_edit_report(file_list, save_name, edits_list=["s","v","q","m"], save_path=edit_report_path, 
                         save_report=True):
    """
    file_list: list of files to check against rules engine
    edits_list: list of edit types to check options are s, v, q, m
    """
    #set up data frame seed for edit report to use as a base for concatenation
    report_df = pd.DataFrame([], columns=['file_name', 'edit_name', 'row_type', 'field', 'fail_count', 'failed_rows', "file_edit_name"], index=[0])
    for file in file_list: #iterate over clean test files and create report results for each
        rules_engine.reset_results() #clear previous edit report results
        #print(file) #display current working file
        ts_df, lar_df = rules_engine.split_ts_row(file) #split TS row from LAR data for dataframe usage
        #load current file data to rules engine to create edit report
        rules_engine.load_ts_data(ts_df)
        rules_engine.load_lar_data(lar_df)
        #generate edit report
        new_results_df = rules_engine.create_edit_report(edits_list)
        new_results_df["file_name"] = file #label file_name in report
        new_results_df["file_edit_name"] = new_results_df.file_name.apply(lambda x: x.split("/")[-1].split("_")[-1].replace(".txt",""))
        report_df = pd.concat([report_df, new_results_df])
        report_df.reset_index(drop=True, inplace=True)
        report_df.drop(0, inplace=True)
    if save_report:
        if not os.path.exists(save_path):
            os.makedirs(save_path)
        report_df.to_csv(save_path + save_name, sep="|", index=False)
    return report_df

### check if all files were created: use rules engine list
#get list of ones missing

# %%
clean_files = get_file_names(clean_filepath)
clean_report_df = generate_edit_report(clean_files, save_name=filepaths['clean_file_report_output_filename'].format(bank_name=bank_config_data["name"]["value"]))
# Out:
# 1 files found in ['../edits_files/Abhinayaa Bank/clean_files/']
# ../edits_files/Abhinayaa Bank/clean_files/Abhinayaa Bank_clean_500_rows.txt
# /Users/roellr/.pyenv/versions/3.6.9/lib/python3.6/site-packages/ipykernel_launcher.py:39: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
clean_report_df[clean_report_df.fail_count>0].edit_name.unique()
# Out:
# array(['q638', 'q646', 'q605_1', 'q605_2', 'q607', 'q608', 'q609', 'q610',
#        'q611', 'q612', 'q613', 'q614_1', 'q614_2', 'q615_2', 'q616_2',
#        'q617', 'q618', 'q619', 'q620', 'q622', 'q627', 'q629', 'q630',
#        'q631', 'q632', 'q633', 'q643', 'q644', 'q648'], dtype=object)

# %%
edit_files = get_file_names(edit_filepaths)
edit_report_df = generate_edit_report(edit_files, save_name=
                                      filepaths['edit_report_output_filename'].format(bank_name=
                                                                                      bank_config_data["name"]["value"]))
# Out:
# 297 files found in ['../edits_files/Abhinayaa Bank/test_files/validity/', '../edits_files/Abhinayaa Bank/test_files/syntax/', '../edits_files/Abhinayaa Bank/test_files/quality/']
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q600.txt
# /Users/roellr/.pyenv/versions/3.6.9/lib/python3.6/site-packages/ipykernel_launcher.py:39: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q601.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q602.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q603.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q605_1.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q605_2.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q606.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q607.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q608.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q609.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q610.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q611.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q612.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q613.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q614_1.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q614_2.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q615_1.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q615_2.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q616_1.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q616_2.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q617.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q618.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q619.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q620.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q621.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q622.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q623.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q624.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q625.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q626.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q627.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q628.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q629.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q630.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q631.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q632.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q633.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q642_1.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q642_2.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q643.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q644.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q645_1.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q645_2.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q648.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q649_1.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q649_2.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q650.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q651.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q652.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q653_1.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q653_2.txt
# ../edits_files/Abhinayaa Bank/test_files/quality/Abhinayaa Bank_500_q654.txt
# ../edits_files/Abhinayaa Bank/test_files/syntax/Abhinayaa Bank_500_s300_1.txt
# ../edits_files/Abhinayaa Bank/test_files/syntax/Abhinayaa Bank_500_s300_2.txt
# ../edits_files/Abhinayaa Bank/test_files/syntax/Abhinayaa Bank_500_s301.txt
# ../edits_files/Abhinayaa Bank/test_files/syntax/Abhinayaa Bank_500_s302.txt
# ../edits_files/Abhinayaa Bank/test_files/syntax/Abhinayaa Bank_500_s304.txt
# ../edits_files/Abhinayaa Bank/test_files/syntax/Abhinayaa Bank_500_s305.txt
# ../edits_files/Abhinayaa Bank/test_files/syntax/Abhinayaa Bank_500_s306.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v600.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v601_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v601_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v601_3.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v601_4.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v601_5.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v602.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v603.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v604.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v605.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v606.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v607.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v608_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v608_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v609.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v610_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v610_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v611.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v612_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v612_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v613_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v613_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v613_3.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v613_4.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v614_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v614_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v614_3.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v614_4.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v615_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v615_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v615_3.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v616.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v617.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v618.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v619_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v619_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v619_3.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v620.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v621.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v622_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v622_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v622_3.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v623.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v624.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v625_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v625_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v626.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v627.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v628_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v628_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v628_3.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v628_4.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v629_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v629_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v629_3.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v630.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v631_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v631_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v631_3.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v631_4.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v632_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v632_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v632_3.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v633.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v634.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v635_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v635_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v635_3.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v635_4.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v636_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v636_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v636_3.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v637.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v638_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v638_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v638_3.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v638_4.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v639_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v639_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v639_3.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v640.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v641.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v642_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v642_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v643.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v644_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v644_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v645.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v646_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v646_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v647.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v648_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v648_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v649.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v650.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v651_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v651_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v652_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v652_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v654_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v654_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v655_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v655_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v656_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v656_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v657_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v657_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v657_3.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v658_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v658_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v659.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v660_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v660_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v661.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v662_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v662_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v663.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v664.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v665_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v665_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v666_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v666_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v667_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v667_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v668_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v668_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v669_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v669_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v669_3.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v669_4.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v670_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v670_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v670_3.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v670_4.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v671_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v671_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v672_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v672_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v672_3.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v672_4.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v672_5.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v672_6.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v673_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v673_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v673_3.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v673_4.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v673_5.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v674_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v674_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v674_3.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v674_4.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v674_5.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v675_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v675_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v675_3.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v675_4.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v675_5.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v676_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v676_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v676_3.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v676_4.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v676_5.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v677_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v677_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v678_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v678_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v678_3.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v678_4.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v678_5.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v679_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v679_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v679_3.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v680_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v680_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v681_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v681_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v682_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v682_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v683.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v684.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v685.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v686.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v687.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v688_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v688_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v689_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v689_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v689_3.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v690_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v690_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v690_3.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v691.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v692_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v692_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v692_3.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v693_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v693_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v693_3.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v694_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v694_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v694_3.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v695.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v696_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v696_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v696_3.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v699.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v700_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v700_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v701.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v702_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v702_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v703_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v703_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v704_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v704_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v705_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v705_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v706.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v707.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v708.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v709.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v710_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v710_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v711.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v712_a.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v712_b.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v713_1.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v713_2.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v714_a.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v714_b.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v715_a.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v715_b.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v715_c.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v715_d.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v716.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v717_a.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v717_b.txt
# ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v717_c.txt

# %%
#edit_report_df[((edit_report_df.file_edit_name.isin(["q648", "q651"]))&(edit_report_df.fail_count>0))&
 #             (edit_report_df.edit_name.apply(lambda x: x[:1] in ("s", "v")))]

edit_report_df[(edit_report_df.file_name==edit_report_df.file_edit_name)]

edit_report_df.file_edit_name.unique()
edit_report_df[["edit_name", "fail_count", "field", "file_edit_name", "file_name", "row_type"]][(edit_report_df.fail_count>=500)&
                                                     (edit_report_df.file_name.apply(lambda x: "q" not in x))&
                                                     (edit_report_df.edit_name.apply(lambda x: x[:1] in ("s", "v")))&
                                                    (edit_report_df.apply(lambda x: ))]
# Out:
#       edit_name fail_count                             field file_edit_name  \
# 15455  s300_2    500        record_id                         2
# 15752  s301      500        LEI                               s301
# 16642  s305      500        all                               s305
# 17232  s301      500        LEI                               v600
# 17236  v600      500        LEI                               v600
# 20800  v609      500        ULI                               1
# 21689  v610_1    500        app_date                          1
# 21710  v619_3    500        action_date                       1
# 21986  v610_2    500        app_date                          2
# 22283  v611      500        loan_type                         v611
# 22580  v612_1    500        loan_purpose                      1
# 22877  v612_2    500        loan_purpose                      2
# 22882  v614_1    500        preapproval                       2
# 23174  v613_1    500        preapproval                       1
# 23471  v613_2    500        preapproval                       2
# 23768  v613_3    500        preapproval                       3
# 23769  v613_4    500        preapproval                       3
# 24065  v613_4    500        preapproval                       4
# 24357  v612_2    500        loan_purpose                      1
# 24362  v614_1    500        preapproval                       1
# 24659  v614_2    500        preapproval                       2
# 24956  v614_3    500        preapproval                       3
# 25253  v614_4    500        preapproval                       4
# 25550  v615_1    500        const_method                      1
# 25847  v615_2    500        const_method                      2
# 26008  v690_3    500        Manufactured Land Interest        2
# 26144  v615_3    500        const_method                      3
# 26301  v689_3    500        Manufactured Property Type        3
# 26441  v616      500        occupancy                         v616
# 26738  v617      500        loan_amount                       v617
# 27035  v618      500        action_taken                      v618
# 27332  v619_1    500        action_date                       1
# 27333  v619_2    500        action_date                       1
# 27629  v619_2    500        action_date                       2
# 27925  v619_2    500        action_date                       3
# 27926  v619_3    500        action_date                       3
# 28223  v620      500        street_address                    v620
# 28520  v621      500        city                              v621
# 28817  v622_1    500        city                              1
# 29114  v622_2    500        state                             2
# 29116  v623      500        state                             2
# 29303  v716      500        state, county                     2
# 29708  v623      500        state                             v623
# 29895  v716      500        state, county                     v623
# 30005  v624      500        zip_code                          v624
# 30302  v625_1    500        tract                             1
# 30303  v625_2    500        tract                             1
# 30305  v627      500        tract/county                      1
# 30599  v625_2    500        tract                             2
# 30601  v627      500        tract/county                      2
# 30896  v626      500        county                            v626
# 30897  v627      500        tract/county                      v626
# 31079  v716      500        state, county                     v626
# 31490  v628_1    500        app_eth_1                         1
# 31787  v628_2    500        app ethnicities 2-4               2
# 31788  v628_3    500        applicant ethnicities             2
# 32084  v628_3    500        applicant ethnicities             3
# 32380  v628_3    500        applicant ethnicities             4
# 32381  v628_4    500        applicant ethnicities             4
# 32678  v629_1    500        app ethnicity basis               1
# 32972  v628_3    500        applicant ethnicities             2
# 32973  v628_4    500        applicant ethnicities             2
# 32975  v629_2    500        app ethnicity basis               2
# 33272  v629_3    500        app ethnicity basis               3
# 33273  v630      500        app ethnicity basis               3
# 33568  v629_3    500        app ethnicity basis               v630
# 33569  v630      500        app ethnicity basis               v630
# 33866  v631_1    500        co-app ethnicities                1
# 34163  v631_2    500        co-app ethnicities                2
# 34164  v631_3    500        Co-App Ethnicities                2
# 34460  v631_3    500        Co-App Ethnicities                3
# 34756  v631_3    500        Co-App Ethnicities                4
# 34757  v631_4    500        Co-App Ethnicities                4
# 35054  v632_1    500        Co-App Ethnicity Basis            1
# 35348  v631_3    500        Co-App Ethnicities                2
# 35349  v631_4    500        Co-App Ethnicities                2
# 35351  v632_2    500        Co-App Ethnicity Basis            2
# 35648  v632_3    500        Co-App Ethnicity Basis            3
# 35649  v633      500        Co-App Ethnicity basis            3
# 35943  v632_2    500        Co-App Ethnicity Basis            v633
# 35945  v633      500        Co-App Ethnicity basis            v633
# 36242  v634      500        Co-App Ethnicity Basis            v634
# 36539  v635_1    500        App Race 1                        1
# 36836  v635_2    500        App Race 2 - 5                    2
# 36837  v635_3    500        Applicant Races                   2
# 37133  v635_3    500        Applicant Races                   3
# 37430  v635_4    500        Applicant Races                   4
# 37727  v636_1    500        Applicant Race Basis              1
# 38019  v635_1    500        App Race 1                        2
# 38020  v635_2    500        App Race 2 - 5                    2
# 38021  v635_3    500        Applicant Races                   2
# 38024  v636_2    500        Applicant Race Basis              2
# 38315  v635_1    500        App Race 1                        3
# 38316  v635_2    500        App Race 2 - 5                    3
# 38317  v635_3    500        Applicant Races                   3
# 38321  v636_3    500        Applicant Race Basis              3
# 38618  v637      500        Applicant Race Basis              v637
# 38915  v638_1    500        Co-Applicant Race 1               1
# 39212  v638_2    500        Co-Applicant Race 2-5             2
# 39213  v638_3    500        Co-Applicant Races                2
# 39509  v638_3    500        Co-Applicant Races                3
# 39805  v638_3    500        Co-Applicant Races                4
# 39806  v638_4    500        Co-Applicant Races                4
# 40103  v639_1    500        Co-Applicant Race Basis           1
# 40397  v638_3    500        Co-Applicant Races                2
# 40400  v639_2    500        Co-Applicant Race Basis           2
# 40692  v638_2    500        Co-Applicant Race 2-5             3
# 40693  v638_3    500        Co-Applicant Races                3
# 40697  v639_3    500        Co-Applicant Race Basis           3
# 40994  v640      500        Co-Applicant Race Basis           v640
# 41291  v641      500        Co-Applicant Race Basis           v641
# 41588  v642_1    500        Applicant Sex                     1
# 41885  v642_2    500        Applicant Sex Basis               2
# 42182  v643      500        Applicant Sex Basis               v643
# 42479  v644_1    500        Applicant Sex                     1
# 42774  v643      500        Applicant Sex Basis               2
# 42776  v644_2    500        Applicant Sex Basis               2
# 43073  v645      500        Applicant Sex Basis               v645
# 43667  v646_2    500        Co-Applicant Sex Basis            2
# 43964  v647      500        Co-Applicant Sex                  v647
# 44261  v648_1    500        Co Applicant Sex                  1
# 44558  v648_2    500        Co-Applicant Sex Basis            2
# 44855  v649      500        Co-Applicant Sex Basis            v649
# 45152  v650      500        Co-Applicant Sex                  v650
# 45449  v651_1    500        Applicant Age                     1
# 46043  v652_1    500        Co-Applicant Age                  1
# 46637  v654_1    500        Income                            1
# 46934  v654_2    500        Income                            2
# 47825  v656_1    500        Type of Purchaser                 1
# 48122  v656_2    500        Type of Purchaser                 2
# 48419  v657_1    500        Rate Spread                       1
# 48716  v657_2    500        Rate Spread                       2
# 49013  v657_3    500        Rate Spread                       3
# 49310  v658_1    500        HOEPA                             1
# 49607  v658_2    500        HOEPA                             2
# 49904  v659      500        Lien Status                       v659
# 50201  v660_1    500        App Credit Score                  1
# 50498  v660_2    500        App Credit Score                  2
# 50795  v661      500        App Credit Score                  v661
# 51093  v662_2    500        App Score Name                    1
# 51388  v662_1    500        App Score Name                    2
# 51389  v662_2    500        App Score Name                    2
# 51686  v663      500        App Credit Score                  v663
# 51983  v664      500        Co-App Credit Score               v664
# 52280  v665_1    500        Co-App Credit Score               1
# 52577  v665_2    500        Co-App Score Name                 2
# 52874  v666_1    500        Co-App Credit Score               1
# 53171  v666_2    500        Co-App Credit Score               2
# 53468  v667_1    500        Co-App Credit Score Text          1
# 53469  v667_2    500        Co-App Credit Score Text          1
# 53764  v667_1    500        Co-App Credit Score Text          2
# 53765  v667_2    500        Co-App Credit Score Text          2
# 54062  v668_1    500        App Credit Score                  1
# 54359  v668_2    500        Co-App Credit Score               2
# 54656  v669_1    500        Denial Reason 1                   1
# 55250  v669_3    500        Denial Reasons 1-4                3
# 55547  v669_4    500        Denial Reasons 1-4                4
# 55844  v670_1    500        Denial Reason 1                   1
# 55847  v670_4    500        Denial Reason 1                   1
# 56141  v670_2    500        Denial Reason 1                   2
# 56142  v670_3    500        Denial Reason 1                   2
# 56437  v670_2    500        Denial Reason 1                   3
# 56438  v670_3    500        Denial Reason 1                   3
# 56732  v670_1    500        Denial Reason 1                   4
# 56735  v670_4    500        Denial Reason 1                   4
# 57026  v669_3    500        Denial Reasons 1-4                1
# 57032  v671_1    500        Denail Reasons 1-4                1
# 57329  v671_2    500        Denial Reasons 1-4                2
# 57626  v672_1    500        Loan Costs                        1
# 57923  v672_2    500        Loan Costs                        2
# 57932  v673_5    500        Points and Fees                   2
# 58220  v672_3    500        Loan Costs                        3
# 58517  v672_4    500        Loan Costs                        4
# 58814  v672_5    500        Loan Costs                        5
# 59111  v672_6    500        Loan Costs                        6
# 59408  v673_1    500        Points and Fees                   1
# 59705  v673_2    500        Points and Fees                   2
# 60002  v673_3    500        Points and Fees                   3
# 60299  v673_4    500        Points and Fees                   4
# 60587  v672_2    500        Loan Costs                        5
# 60596  v673_5    500        Points and Fees                   5
# 60893  v674_1    500        Origination Charges               1
# 61190  v674_2    500        Origination Charges               2
# 61487  v674_3    500        Origination Charges               3
# 61784  v674_4    500        Origination Charges               4
# 62081  v674_5    500        Origination Charges               5
# 62378  v675_1    500        Discount Points                   1
# 62675  v675_2    500        Discount Points                   2
# 62972  v675_3    500        Discount Points                   3
# 63269  v675_4    500        Discount Points                   4
# 63566  v675_5    500        Discount Points                   5
# 63863  v676_1    500        Lender Credits                    1
# 64160  v676_2    500        Lender Credits                    2
# 64457  v676_3    500        Lender Credits                    3
# 64754  v676_4    500        Lender Credits                    4
# 65051  v676_5    500        Lender Credits                    5
# 65348  v677_1    500        Interest Rate                     1
# 65645  v677_2    500        Interest Rate                     2
# 65942  v678_1    500        Prepayment Term                   1
# 66239  v678_2    500        Prepayment Term                   2
# 66536  v678_3    500        Prepayment Term                   3
# 66833  v678_4    500        Prepayment Term                   4
# 67130  v678_5    500        Prepayment Term                   5
# 67427  v679_1    500        DTI                               1
# 67724  v679_2    500        DTI                               2
# 68021  v679_3    500        DTI                               3
# 68318  v680_1    500        DTI                               1
# 68615  v680_2    500        DTI                               2
# 68912  v681_1    500        CLTV                              1
# 69209  v681_2    500        CLTV                              2
# 69506  v682_1    500        Loan Term                         1
# 69803  v682_2    500        Loan Term                         2
# 70100  v683      500        Introductory Rate                 v683
# 70397  v684      500        Balloon Payment                   v684
# 70694  v685      500        Interest Only Payments            v685
# 70991  v686      500        Negative Amortization             v686
# 71288  v687      500        Non-amortizing Features           v687
# 71585  v688_1    500        Property Value                    1
# 71882  v688_2    500        Property Value                    2
# 72179  v689_1    500        Manufactured Property Type        1
# 72476  v689_2    500        Manufactured Property Type        2
# 72616  v615_3    500        const_method                      3
# 72773  v689_3    500        Manufactured Property Type        3
# 73070  v690_1    500        Manufactured Land Interest        1
# 73367  v690_2    500        Manufactured Land Interest        2
# 73503  v615_2    500        const_method                      3
# 73664  v690_3    500        Manufactured Land Interest        3
# 73961  v691      500        Total Units                       v691
# 74260  v692_3    500        Affordable Units                  1
# 74555  v692_2    500        Affordable Units                  2
# 74852  v692_3    500        Affordable Units                  3
# 75149  v693_1    500        Applicaiton Submission            1
# 75446  v693_2    500        Applicaiton Channel               2
# 75743  v693_3    500        Application Channel               3
# 76040  v694_1    500        initially_payable                 1
# 76337  v694_2    500        initially_payable                 2
# 76634  v694_3    500        initially_payable                 3
# 76931  v695      500        NMLS ID                           v695
# 77228  v696_1    500        AUS 1-5                           1
# 77230  v696_3    500        AUS Systems and Results           1
# 77525  v696_2    500        AUS 1-5 Result                    2
# 77530  v701      500        AUS and Results                   2
# 77822  v696_3    500        AUS Systems and Results           3
# 77826  v701      500        AUS and Results                   3
# 78117  v696_2    500        AUS 1-5 Result                    v699
# 78118  v696_3    500        AUS Systems and Results           v699
# 78119  v699      500        AUS and Results                   v699
# 78414  v696_3    500        AUS Systems and Results           1
# 78416  v700_1    500        AUS and Results                   1
# 78418  v701      500        AUS and Results                   1
# 78710  v696_3    500        AUS Systems and Results           2
# 78713  v700_2    500        AUS and Results                   2
# 78714  v701      500        AUS and Results                   2
# 79006  v696_3    500        AUS Systems and Results           v701
# 79010  v701      500        AUS and Results                   v701
# 79307  v702_1    500        AUS                               1
# 79598  v696_3    500        AUS Systems and Results           2
# 79604  v702_2    500        AUS                               2
# 79901  v703_1    500        AUS Results                       1
# 80190  v696_3    500        AUS Systems and Results           2
# 80194  v701      500        AUS and Results                   2
# 80198  v703_2    500        AUS Results                       2
# 80495  v704_1    500        AUS                               1
# 80792  v704_2    500        AUS Result                        2
# 81089  v705_1    500        AUS and Results                   1
# 81386  v705_2    500        AUS and Results                   2
# 81683  v706      500        Reverse Mortgage                  v706
# 81980  v707      500        Open End Credit                   v707
# 82277  v708      500        Business Purpose                  v708
# 82574  v709      500        Property Address                  v709
# 82871  v710_1    500        Credit Score                      1
# 82872  v710_2    500        Credit Score                      1
# 83167  v710_1    500        Credit Score                      2
# 83168  v710_2    500        Credit Score                      2
# 83371  v669_4    500        Denial Reasons 1-4                v711
# 83465  v711      500        Reason for Denial                 v711
# 83675  v672_2    500        Loan Costs                        a
# 83762  v712      500        Total Loan Costs/Points and Fees  a
# 83980  v673_5    500        Points and Fees                   b
# 84058  v712      500        Total Loan Costs/Points and Fees  b
# 84355  v713_1    500        Automated Underwriting System     1
# 84636  v702_2    500        AUS                               2
# 84638  v703_2    500        AUS Results                       2
# 84651  v713_1    500        Automated Underwriting System     2
# 84652  v713_2    500        Automated Underwriting System     2
# 84949  v714      500        Application Channel               a
# 85245  v714      500        Application Channel               b
# 85542  v715      500        Non-Amortizing Features           a
# 85838  v715      500        Non-Amortizing Features           b
# 86134  v715      500        Non-Amortizing Features           c
# 86430  v715      500        Non-Amortizing Features           d
# 86727  v716      500        state, county                     v716
#
#                                                                              file_name  \
# 15455  ../edits_files/Abhinayaa Bank/test_files/syntax/Abhinayaa Bank_500_s300_2.txt
# 15752  ../edits_files/Abhinayaa Bank/test_files/syntax/Abhinayaa Bank_500_s301.txt
# 16642  ../edits_files/Abhinayaa Bank/test_files/syntax/Abhinayaa Bank_500_s305.txt
# 17232  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v600.txt
# 17236  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v600.txt
# 20800  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v608_1.txt
# 21689  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v610_1.txt
# 21710  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v610_1.txt
# 21986  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v610_2.txt
# 22283  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v611.txt
# 22580  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v612_1.txt
# 22877  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v612_2.txt
# 22882  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v612_2.txt
# 23174  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v613_1.txt
# 23471  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v613_2.txt
# 23768  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v613_3.txt
# 23769  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v613_3.txt
# 24065  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v613_4.txt
# 24357  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v614_1.txt
# 24362  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v614_1.txt
# 24659  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v614_2.txt
# 24956  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v614_3.txt
# 25253  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v614_4.txt
# 25550  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v615_1.txt
# 25847  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v615_2.txt
# 26008  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v615_2.txt
# 26144  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v615_3.txt
# 26301  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v615_3.txt
# 26441  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v616.txt
# 26738  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v617.txt
# 27035  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v618.txt
# 27332  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v619_1.txt
# 27333  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v619_1.txt
# 27629  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v619_2.txt
# 27925  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v619_3.txt
# 27926  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v619_3.txt
# 28223  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v620.txt
# 28520  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v621.txt
# 28817  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v622_1.txt
# 29114  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v622_2.txt
# 29116  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v622_2.txt
# 29303  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v622_2.txt
# 29708  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v623.txt
# 29895  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v623.txt
# 30005  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v624.txt
# 30302  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v625_1.txt
# 30303  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v625_1.txt
# 30305  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v625_1.txt
# 30599  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v625_2.txt
# 30601  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v625_2.txt
# 30896  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v626.txt
# 30897  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v626.txt
# 31079  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v626.txt
# 31490  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v628_1.txt
# 31787  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v628_2.txt
# 31788  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v628_2.txt
# 32084  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v628_3.txt
# 32380  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v628_4.txt
# 32381  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v628_4.txt
# 32678  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v629_1.txt
# 32972  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v629_2.txt
# 32973  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v629_2.txt
# 32975  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v629_2.txt
# 33272  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v629_3.txt
# 33273  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v629_3.txt
# 33568  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v630.txt
# 33569  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v630.txt
# 33866  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v631_1.txt
# 34163  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v631_2.txt
# 34164  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v631_2.txt
# 34460  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v631_3.txt
# 34756  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v631_4.txt
# 34757  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v631_4.txt
# 35054  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v632_1.txt
# 35348  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v632_2.txt
# 35349  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v632_2.txt
# 35351  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v632_2.txt
# 35648  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v632_3.txt
# 35649  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v632_3.txt
# 35943  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v633.txt
# 35945  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v633.txt
# 36242  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v634.txt
# 36539  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v635_1.txt
# 36836  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v635_2.txt
# 36837  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v635_2.txt
# 37133  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v635_3.txt
# 37430  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v635_4.txt
# 37727  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v636_1.txt
# 38019  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v636_2.txt
# 38020  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v636_2.txt
# 38021  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v636_2.txt
# 38024  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v636_2.txt
# 38315  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v636_3.txt
# 38316  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v636_3.txt
# 38317  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v636_3.txt
# 38321  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v636_3.txt
# 38618  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v637.txt
# 38915  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v638_1.txt
# 39212  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v638_2.txt
# 39213  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v638_2.txt
# 39509  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v638_3.txt
# 39805  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v638_4.txt
# 39806  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v638_4.txt
# 40103  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v639_1.txt
# 40397  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v639_2.txt
# 40400  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v639_2.txt
# 40692  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v639_3.txt
# 40693  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v639_3.txt
# 40697  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v639_3.txt
# 40994  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v640.txt
# 41291  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v641.txt
# 41588  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v642_1.txt
# 41885  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v642_2.txt
# 42182  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v643.txt
# 42479  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v644_1.txt
# 42774  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v644_2.txt
# 42776  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v644_2.txt
# 43073  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v645.txt
# 43667  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v646_2.txt
# 43964  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v647.txt
# 44261  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v648_1.txt
# 44558  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v648_2.txt
# 44855  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v649.txt
# 45152  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v650.txt
# 45449  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v651_1.txt
# 46043  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v652_1.txt
# 46637  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v654_1.txt
# 46934  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v654_2.txt
# 47825  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v656_1.txt
# 48122  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v656_2.txt
# 48419  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v657_1.txt
# 48716  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v657_2.txt
# 49013  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v657_3.txt
# 49310  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v658_1.txt
# 49607  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v658_2.txt
# 49904  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v659.txt
# 50201  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v660_1.txt
# 50498  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v660_2.txt
# 50795  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v661.txt
# 51093  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v662_1.txt
# 51388  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v662_2.txt
# 51389  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v662_2.txt
# 51686  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v663.txt
# 51983  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v664.txt
# 52280  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v665_1.txt
# 52577  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v665_2.txt
# 52874  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v666_1.txt
# 53171  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v666_2.txt
# 53468  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v667_1.txt
# 53469  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v667_1.txt
# 53764  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v667_2.txt
# 53765  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v667_2.txt
# 54062  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v668_1.txt
# 54359  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v668_2.txt
# 54656  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v669_1.txt
# 55250  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v669_3.txt
# 55547  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v669_4.txt
# 55844  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v670_1.txt
# 55847  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v670_1.txt
# 56141  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v670_2.txt
# 56142  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v670_2.txt
# 56437  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v670_3.txt
# 56438  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v670_3.txt
# 56732  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v670_4.txt
# 56735  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v670_4.txt
# 57026  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v671_1.txt
# 57032  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v671_1.txt
# 57329  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v671_2.txt
# 57626  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v672_1.txt
# 57923  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v672_2.txt
# 57932  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v672_2.txt
# 58220  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v672_3.txt
# 58517  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v672_4.txt
# 58814  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v672_5.txt
# 59111  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v672_6.txt
# 59408  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v673_1.txt
# 59705  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v673_2.txt
# 60002  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v673_3.txt
# 60299  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v673_4.txt
# 60587  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v673_5.txt
# 60596  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v673_5.txt
# 60893  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v674_1.txt
# 61190  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v674_2.txt
# 61487  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v674_3.txt
# 61784  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v674_4.txt
# 62081  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v674_5.txt
# 62378  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v675_1.txt
# 62675  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v675_2.txt
# 62972  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v675_3.txt
# 63269  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v675_4.txt
# 63566  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v675_5.txt
# 63863  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v676_1.txt
# 64160  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v676_2.txt
# 64457  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v676_3.txt
# 64754  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v676_4.txt
# 65051  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v676_5.txt
# 65348  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v677_1.txt
# 65645  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v677_2.txt
# 65942  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v678_1.txt
# 66239  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v678_2.txt
# 66536  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v678_3.txt
# 66833  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v678_4.txt
# 67130  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v678_5.txt
# 67427  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v679_1.txt
# 67724  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v679_2.txt
# 68021  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v679_3.txt
# 68318  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v680_1.txt
# 68615  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v680_2.txt
# 68912  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v681_1.txt
# 69209  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v681_2.txt
# 69506  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v682_1.txt
# 69803  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v682_2.txt
# 70100  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v683.txt
# 70397  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v684.txt
# 70694  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v685.txt
# 70991  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v686.txt
# 71288  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v687.txt
# 71585  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v688_1.txt
# 71882  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v688_2.txt
# 72179  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v689_1.txt
# 72476  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v689_2.txt
# 72616  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v689_3.txt
# 72773  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v689_3.txt
# 73070  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v690_1.txt
# 73367  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v690_2.txt
# 73503  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v690_3.txt
# 73664  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v690_3.txt
# 73961  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v691.txt
# 74260  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v692_1.txt
# 74555  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v692_2.txt
# 74852  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v692_3.txt
# 75149  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v693_1.txt
# 75446  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v693_2.txt
# 75743  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v693_3.txt
# 76040  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v694_1.txt
# 76337  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v694_2.txt
# 76634  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v694_3.txt
# 76931  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v695.txt
# 77228  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v696_1.txt
# 77230  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v696_1.txt
# 77525  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v696_2.txt
# 77530  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v696_2.txt
# 77822  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v696_3.txt
# 77826  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v696_3.txt
# 78117  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v699.txt
# 78118  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v699.txt
# 78119  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v699.txt
# 78414  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v700_1.txt
# 78416  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v700_1.txt
# 78418  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v700_1.txt
# 78710  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v700_2.txt
# 78713  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v700_2.txt
# 78714  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v700_2.txt
# 79006  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v701.txt
# 79010  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v701.txt
# 79307  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v702_1.txt
# 79598  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v702_2.txt
# 79604  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v702_2.txt
# 79901  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v703_1.txt
# 80190  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v703_2.txt
# 80194  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v703_2.txt
# 80198  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v703_2.txt
# 80495  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v704_1.txt
# 80792  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v704_2.txt
# 81089  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v705_1.txt
# 81386  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v705_2.txt
# 81683  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v706.txt
# 81980  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v707.txt
# 82277  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v708.txt
# 82574  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v709.txt
# 82871  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v710_1.txt
# 82872  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v710_1.txt
# 83167  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v710_2.txt
# 83168  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v710_2.txt
# 83371  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v711.txt
# 83465  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v711.txt
# 83675  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v712_a.txt
# 83762  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v712_a.txt
# 83980  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v712_b.txt
# 84058  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v712_b.txt
# 84355  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v713_1.txt
# 84636  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v713_2.txt
# 84638  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v713_2.txt
# 84651  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v713_2.txt
# 84652  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v713_2.txt
# 84949  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v714_a.txt
# 85245  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v714_b.txt
# 85542  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v715_a.txt
# 85838  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v715_b.txt
# 86134  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v715_c.txt
# 86430  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v715_d.txt
# 86727  ../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v716.txt
#
#       row_type
# 15455  LAR
# 15752  TS
# 16642  LAR
# 17232  TS
# 17236  LAR
# 20800  LAR
# 21689  LAR
# 21710  LAR
# 21986  LAR
# 22283  LAR
# 22580  LAR
# 22877  LAR
# 22882  LAR
# 23174  LAR
# 23471  LAR
# 23768  LAR
# 23769  LAR
# 24065  LAR
# 24357  LAR
# 24362  LAR
# 24659  LAR
# 24956  LAR
# 25253  LAR
# 25550  LAR
# 25847  LAR
# 26008  LAR
# 26144  LAR
# 26301  LAR
# 26441  LAR
# 26738  LAR
# 27035  LAR
# 27332  LAR
# 27333  LAR
# 27629  LAR
# 27925  LAR
# 27926  LAR
# 28223  LAR
# 28520  LAR
# 28817  LAR
# 29114  LAR
# 29116  LAR
# 29303  LAR
# 29708  LAR
# 29895  LAR
# 30005  LAR
# 30302  LAR
# 30303  LAR
# 30305  LAR
# 30599  LAR
# 30601  LAR
# 30896  LAR
# 30897  LAR
# 31079  LAR
# 31490  LAR
# 31787  LAR
# 31788  LAR
# 32084  LAR
# 32380  LAR
# 32381  LAR
# 32678  LAR
# 32972  LAR
# 32973  LAR
# 32975  LAR
# 33272  LAR
# 33273  LAR
# 33568  LAR
# 33569  LAR
# 33866  LAR
# 34163  LAR
# 34164  LAR
# 34460  LAR
# 34756  LAR
# 34757  LAR
# 35054  LAR
# 35348  LAR
# 35349  LAR
# 35351  LAR
# 35648  LAR
# 35649  LAR
# 35943  LAR
# 35945  LAR
# 36242  LAR
# 36539  LAR
# 36836  LAR
# 36837  LAR
# 37133  LAR
# 37430  LAR
# 37727  LAR
# 38019  LAR
# 38020  LAR
# 38021  LAR
# 38024  LAR
# 38315  LAR
# 38316  LAR
# 38317  LAR
# 38321  LAR
# 38618  LAR
# 38915  LAR
# 39212  LAR
# 39213  LAR
# 39509  LAR
# 39805  LAR
# 39806  LAR
# 40103  LAR
# 40397  LAR
# 40400  LAR
# 40692  LAR
# 40693  LAR
# 40697  LAR
# 40994  LAR
# 41291  LAR
# 41588  LAR
# 41885  LAR
# 42182  LAR
# 42479  LAR
# 42774  LAR
# 42776  LAR
# 43073  LAR
# 43667  LAR
# 43964  LAR
# 44261  LAR
# 44558  LAR
# 44855  LAR
# 45152  LAR
# 45449  LAR
# 46043  LAR
# 46637  LAR
# 46934  LAR
# 47825  LAR
# 48122  LAR
# 48419  LAR
# 48716  LAR
# 49013  LAR
# 49310  LAR
# 49607  LAR
# 49904  LAR
# 50201  LAR
# 50498  LAR
# 50795  LAR
# 51093  LAR
# 51388  LAR
# 51389  LAR
# 51686  LAR
# 51983  LAR
# 52280  LAR
# 52577  LAR
# 52874  LAR
# 53171  LAR
# 53468  LAR
# 53469  LAR
# 53764  LAR
# 53765  LAR
# 54062  LAR
# 54359  LAR
# 54656  LAR
# 55250  LAR
# 55547  LAR
# 55844  LAR
# 55847  LAR
# 56141  LAR
# 56142  LAR
# 56437  LAR
# 56438  LAR
# 56732  LAR
# 56735  LAR
# 57026  LAR
# 57032  LAR
# 57329  LAR
# 57626  LAR
# 57923  LAR
# 57932  LAR
# 58220  LAR
# 58517  LAR
# 58814  LAR
# 59111  LAR
# 59408  LAR
# 59705  LAR
# 60002  LAR
# 60299  LAR
# 60587  LAR
# 60596  LAR
# 60893  LAR
# 61190  LAR
# 61487  LAR
# 61784  LAR
# 62081  LAR
# 62378  LAR
# 62675  LAR
# 62972  LAR
# 63269  LAR
# 63566  LAR
# 63863  LAR
# 64160  LAR
# 64457  LAR
# 64754  LAR
# 65051  LAR
# 65348  LAR
# 65645  LAR
# 65942  LAR
# 66239  LAR
# 66536  LAR
# 66833  LAR
# 67130  LAR
# 67427  LAR
# 67724  LAR
# 68021  LAR
# 68318  LAR
# 68615  LAR
# 68912  LAR
# 69209  LAR
# 69506  LAR
# 69803  LAR
# 70100  LAR
# 70397  LAR
# 70694  LAR
# 70991  LAR
# 71288  LAR
# 71585  LAR
# 71882  LAR
# 72179  LAR
# 72476  LAR
# 72616  LAR
# 72773  LAR
# 73070  LAR
# 73367  LAR
# 73503  LAR
# 73664  LAR
# 73961  LAR
# 74260  LAR
# 74555  LAR
# 74852  LAR
# 75149  LAR
# 75446  LAR
# 75743  LAR
# 76040  LAR
# 76337  LAR
# 76634  LAR
# 76931  LAR
# 77228  LAR
# 77230  LAR
# 77525  LAR
# 77530  LAR
# 77822  LAR
# 77826  LAR
# 78117  LAR
# 78118  LAR
# 78119  LAR
# 78414  LAR
# 78416  LAR
# 78418  LAR
# 78710  LAR
# 78713  LAR
# 78714  LAR
# 79006  LAR
# 79010  LAR
# 79307  LAR
# 79598  LAR
# 79604  LAR
# 79901  LAR
# 80190  LAR
# 80194  LAR
# 80198  LAR
# 80495  LAR
# 80792  LAR
# 81089  LAR
# 81386  LAR
# 81683  LAR
# 81980  LAR
# 82277  LAR
# 82574  LAR
# 82871  LAR
# 82872  LAR
# 83167  LAR
# 83168  LAR
# 83371  LAR
# 83465  LAR
# 83675  LAR
# 83762  LAR
# 83980  LAR
# 84058  LAR
# 84355  LAR
# 84636  LAR
# 84638  LAR
# 84651  LAR
# 84652  LAR
# 84949  LAR
# 85245  LAR
# 85542  LAR
# 85838  LAR
# 86134  LAR
# 86430  LAR
# 86727  LAR

# %%
data_file = "../edits_files/Abhinayaa Bank/test_files/validity/Abhinayaa Bank_500_v673_1.txt"
ts_df, lar_df = rules_engine.split_ts_row(data_file)
lar_df.head()
type(lar_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Read Edit Reports

# %%
def get_fail_ulis(report_df, edit_name_list, file_name):
    """
    returns a list of ULIs failing the specified edits
    edit_name_list: list of edits IE q648
    file_name: name of file in edit report IE Chynna Bank_clean_500_rows.txt
    """
    fail_rows = report_df.failed_rows[(report_df.file_name==file_name)&
               (report_df.edit_name.isin(edit_name_list))].iloc[0]
    fail_rows = fail_rows.strip("']['").split(", ")
    fail_rows = [row.replace("'","") for row in fail_rows]
    return fail_rows

# %%
clean_report_df = pd.read_csv(edit_report_path + \
                             filepaths['clean_file_report_output_filename'].format(bank_name=bank_config_data["name"]["value"]),
                            sep="|")

clean_report_df[(clean_report_df.file_name=="Chynna Bank_clean_500_rows.txt")&
               (clean_report_df.edit_name.isin(["q648"]))]

q648_fails = get_fail_ulis(clean_report_df, ["q648"], "Chynna Bank_clean_500_rows.txt")
clean_report_df[(clean_report_df.file_name=="Chynna Bank_clean_500_rows.txt")&
               (clean_report_df.failed_rows.apply(lambda x: len(x) !=2))]

clean_report_df[clean_report_df.edit_name.apply(lambda x: x[:1]=="v")]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-e1f4320305cc> in <module>
#       6                (clean_report_df.edit_name.isin(["q648"]))]
#       7
# ----> 8 q648_fails = get_fail_ulis(clean_report_df, ["q648"], "Chynna Bank_clean_500_rows.txt")
#       9 clean_report_df[(clean_report_df.file_name=="Chynna Bank_clean_500_rows.txt")&
#      10                (clean_report_df.failed_rows.apply(lambda x: len(x) !=2))]
#
# <ipython-input-12-e2ed4f971768> in get_fail_ulis(report_df, edit_name_list, file_name)
#       6     """
#       7     fail_rows = report_df.failed_rows[(report_df.file_name==file_name)&
# ----> 8                (report_df.edit_name.isin(edit_name_list))].iloc[0]
#       9     fail_rows = fail_rows.strip("']['").split(", ")
#      10     fail_rows = [row.replace("'","") for row in fail_rows]
#
# ~/.pyenv/versions/3.6.9/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# ~/.pyenv/versions/3.6.9/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2155
#    2156             # validate the location
# -> 2157             self._validate_integer(key, axis)
#    2158
#    2159             return self._get_loc(key, axis=axis)
#
# ~/.pyenv/versions/3.6.9/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    2086         len_axis = len(self.obj._get_axis(axis))
#    2087         if key >= len_axis or key < -len_axis:
# -> 2088             raise IndexError("single positional indexer is out-of-bounds")
#    2089
#    2090     def _getitem_tuple(self, tup):
#
# IndexError: single positional indexer is out-of-bounds

# %%
print(bank_clean_dir)
col_list = ["action_taken", "uli", "lei"]
test_file_df = pd.read_csv(bank_clean_dir+"Chynna Bank_clean_500_rows.txt", sep="|", header=None, names=lar_2018_header,
                           skiprows=[0], dtype=object)
test_file_df[col_list][test_file_df.uli.isin(q648_fails)]

# %% [markdown]
# #1) If Action Taken equals 1, 2, 3, 4, 5, 7, or 8, the first
# 20 characters of the ULI should match the reported
# LEI.

# %%
#load edit file report
test_report_df = pd.read_csv(edit_report_path + \
                             filepaths['edit_report_output_filename'].format(bank_name=bank_config_data["name"]["value"]),
                            sep="|")

test_report_df[test_report_df.file_name=="../edits_files/Chynna Bank/test_files/quality/Chynna Bank_500_q648.txt"]
test_report_df.iloc[:,:-2][test_report_df.edit_name=="v610_2"]

# %%
test_file_df = pd.read_csv("../edits_files/Chynna Bank/test_files/quality/Chynna Bank_500_q651.txt", sep="|", header=None, names=lar_2018_header,
                           skiprows=[0], dtype=object, keep_default_na=False)
test_file_df[["action_taken", "app_date"]]#[(test_file_df.action_taken.isin(["6"]))]#&(~test_file_df.app_date.isin(["NA"]))]

# %%
len(test_file_df[((test_file_df.app_date=="NA")&(test_file_df.action_taken!="6"))|
				((test_file_df.action_taken=="6")&(test_file_df.app_date!="NA"))])

# %%
test_report_df
